# %%
import sys
print(sys.executable)
# Out:
# c:\Users\HP\OneDrive\Desktop\LowPrepShristi\Low_Prep_Product_Analyst_shristi\product_env\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
